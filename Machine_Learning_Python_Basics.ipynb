# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavpathak999/Machine-Learning-Course-/blob/master/Machine_Learning_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pattern
#
# 1        1
# 12      21
# 123    321
# 1234  4321
# 1234554321

# %%
n=int(input())
for i in range(n):
    for j in range(1,n+1):
        if j<(i+2):
            print(j,end="")
        else:
            print(" ",end="")
    for j in range(n,0,-1):
        if j>i+1:
            print(" ",end="")
        else:
            print(j,end="")
    print()
# Out:
# 6
# 1          1
# 12        21
# 123      321
# 1234    4321
# 12345  54321
# 123456654321

# %% [markdown]
# # Reversing Strings

# %%
string = input()
string= string + " "
count=0
for i in range(len(string)):
    if string[i]==" ":
        for k in range(i-1,i-count-1,-1):
            print(string[k],end="")
        count=0
        print(" ",end="")
    else:
        count += 1
# Out:
# my name is Vaibhav
# ym eman si vahbiaV

# %% [markdown]
# # Sum of even fibonacci numbers

# %%
n = int(input())
sum=0
k=0
m=1

while k <= n :
    term = k+m
    print(k)
    if k%2==0:
        sum=sum + k
    k=m
    m=term
    
print(sum)
# Out:
# 8
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 10

# %% [markdown]
# # Reversing Series Pattern
#
# for n=5
#
# 1
# 3 2
# 4 5 6
# 10 9 8 7
# 11 12 13 14 15

# %%
n = int(input())
k=1
for i in range(1,n+1):
    if i%2!=0:
        for j in range(i):
            print(k,end=" ")
            k=k+1
        print()    
    else:
        for j in range(i,0,-1):
            print(k+j-1,end=" ")
        print()
        k=k+i
# Out:
# 5
# 1
# 3 2
# 4 5 6
# 10 9 8 7
# 11 12 13 14 15

# %% [markdown]
# # All Prime Numbers

# %%
n = int(input())
k=2
while k<=n:
    flag = True
    i=2
    while i<=k//2:
        if k%i==0:
            flag = False
            break
        i=i+1
    if flag == True:
        print(k)
    k=k+1
# Out:
# 12
# 2
# 3
# 5
# 7
# 11

# %% [markdown]
# # Trailing Zeroes in n!

# %%
import time
n = int(input())
count = 0
i=5
a = time.time()
while n/i>0:
    count = count + n//i
    i=i*5    
b=time.time()        
print(five)
print(b-a)
# Out:
# 8386931
# 2096728
# 0.007949352264404297

# %% [markdown]
# # Decimal to Binary

# %%
binary=[]
decimal = int(input())
if decimal ==0:
    print("0")
while decimal >0:
    rem = decimal %2
    binary.append(rem)
    decimal = decimal//2

for i in range(len(binary)-1,-1,-1):
    print(binary[i],end="")
# Out:
# 0
# 0

# %% [markdown]
# # Selection Sort

# %%
l=[5,6,1,9,0,33,44,2]
l
# Out:
# [5, 6, 1, 9, 0, 33, 44, 2]

# %%
l=[1,7,14,0,9,4,18,18,2,4,5]
for j in range(len(l)-1):
    for i in range(j,len(l)-1):
        if l[j]>=l[i+1]:
            l[j],l[i+1]=l[i+1],l[j]
print(l)
# Out:
# [0, 1, 2, 4, 4, 5, 7, 9, 14, 18, 18]

# %% [markdown]
# # Find the equilibrium Index

# %%
def equilibriumIndex(arr):
    sumFArray=[]
    sumBArray=[]
    sumF=0
    sumB=0
    for i in range(n):
        sumF=arr[i]+sumF
        sumFArray.append(sumF)
        sumB = sumB + arr[-i-1]
        sumBArray.append(sumB)
    for i in range(len(sumFArray)):
        if sumFArray[i]==sumBArray[-i-1]:
            return i
    else:
        return -1
            
                
                
# Main
n = int(input())
arr = [int(i) for i in input().strip().split()]
print(equilibriumIndex(arr))
# Out:
# 5966
# ...

# %% [markdown]
# ### Maximise the path sum of two arrays: If unsorted

# %%
m= int(input())
arr1=list(int(x) for x in input().strip().split(" "))
n=int(input())
arr2=list(int(x) for x in input().strip().split(" "))
sum1=[]
sum2=[]
Sum1=arr1[0]
Sum2=arr2[0]
index2=0
i=0
j=0
value = False
while i < m:
    j=0
    Sum2=0
    while j < n:
        if arr2[j]==arr1[i]:
            Sum2=Sum2+arr2[j]
            sum1.append(Sum1)
            sum2.append(Sum2)
            Sum1=Sum2=0
            j=j+1
            index2=j
            break
        elif arr2[j]!=arr1[i] and j>=index2:
            Sum2=Sum2+arr2[j]
            j=j+1
        else:
            j=j+1        
    i=i+1
    if i<m:
        Sum1 = Sum1 + arr1[i]
if m<n:
    t=m-1
    while t<n:
        Sum2=Sum2+arr2[t]
        t=t+1
    sum2.append(Sum2)    
if m>n:
    sum1.append(Sum1)
if n<m and len(sum1)==len(sum2):
    sum2.append(Sum2)
        
if len(sum1)==0 and len(sum2)==0:
    MaximumSum = max(Sum1,Sum2)
else:
    p=max(len(sum1),len(sum2))
    MaximumSum=0
    k=0
    r=min(len(sum1),len(sum2))
    while k < p:
        if k < r:
            if sum1[k]<sum2[k]:
                MaximumSum = MaximumSum + sum2[k]
                k=k+1
            else:
                MaximumSum = MaximumSum + sum1[k]
                k=k+1
        else:
            if m>n:
                MaximumSum = MaximumSum + sum1[k]
                k=k+1
            else:
                MaximumSum = MaximumSum + sum2[k]
                k=k+1

print(MaximumSum)
# Out:
# 5
# 2 4 5 9 15
# 6
# 1 5 10 15 20 25
# 81

# %% [markdown]
# ### Maximise the path sum if two arraays are sorted

# %%
def maxPathSum(ar1,ar2 , m , n): 
      
    # initialize indexes for ar1[] and ar2[] 
    i, j = 0, 0
      
    # Initialize result and current sum through ar1[] and ar2[] 
    result, sum1, sum2= 0, 0, 0
      
    # Below 3 loops are similar to merge in merge sort 
    while (i < m and j < n): 
        
        # Add elements of ar1[] to sum1 
        if ar1[i] < ar2[j]: 
            sum1 += ar1[i] 
            i+=1
          
        # Add elements of ar2[] to sum1     
        elif ar1[i] > ar2[j]: 
            sum2 += ar2[j] 
            j+=1
          
        else:   # we reached a common point 
          
            # Take the maximum of two sums and add to result 
            result+= max(sum1,sum2) 
              
            # Update sum1 and sum2 for elements after this intersection point 
            sum1, sum2 = 0, 0
              
            # Keep updating result while there are more common elements 
            while (i < m and j < n and ar1[i]==ar2[j]): 
                result += ar1[i] 
                i+=1
                j+=1
      
    # Add remaining elements of ar1[] 
    while i < m: 
        sum1 += ar1[i] 
        i+=1
    # Add remaining elements of b[] 
    while j < n: 
        sum2 += ar2[j] 
        j+=1
      
    # Add maximum of two sums of remaining elements 
    result += max(sum1,sum2) 
      
    return result 
  
# Driver function 
m= int(input())
ar1=list(int(x) for x in input().strip().split(" "))
n=int(input())
ar2=list(int(x) for x in input().strip().split(" ")) 
print(maxPathSum(ar1, ar2, m, n))
# Out:
# 6
# 1 5 10 15 20 25
# 5
# 2 4 5 9 15
# Maximum sum path is 81

# %% [markdown]
# # Find Leaders in  Array
#  An array element A[i] is called Leader, if all the elements following it (i.e. present at its right) are less than or equal to A[i].

# %%
n=int(input())
List = [int(x) for x in input().strip().split(" ")]
for i in range(n):
    k=True
    for j in range(i+1,n):
        if List[i]<List[j]:
            k=False
            break
    if k==True:
        print(List[i],end=" ")
# Out:
# 975
# ...

# %% [markdown]
# # Reverse the string word wise
#
# Welcome to Coding Ninjas
# Ninjas Coding to Welcome

# %%
string = input()
string=string+" "
k=0
ReversedString=""
for i in range(len(string)):
    if string[i]==" ":
        ReversedString =string[k:i+1]+ ReversedString 
        k=i
print(ReversedString.strip())

# %% [markdown]
# # Find Largest Unique Substring

# %%
string = input()
largeSub=[]

for i in range(len(string)-1):
    k=True
    subString=[]
    for j in range(i+1,len(string)-1):
            subString=string[i:j+1]
            j=True
            for k in range(len(subString)-1):
                fake=subString[0:k]+subString[k+1:]
                if subString[k] in fake:
                    j=False
                    break
            if j==True:
                if len(subString)>len(largeSub):
                    largeSub=subString

                                       
print(largeSub)
# Out:
# uhuchwucdshhdbhjcdchbbdhdb
# hwucds

# %% [markdown]
# # Help function trying for above problem

# %%
subString="wucddsh"
largeString=""
part=""
j=False
for k in range(len(subString)-2):
    fake=subString[0:k]+subString[k+1:]
    if subString[k] in fake:
        j=True
        print("hey")
        break
 
if j==False:
    if len(subString)>len(largeString):
        largeString=subString
        
print(largeString)
# Out:
# hey

# %% [markdown]
# # Largest Row or Column
# Send Feedback
# Given an NxM 2D array, you need to find out which row or column has largest sum (sum of its elements) overall amongst all rows and columns.

# %%
def LargestRoworColumn(arr):
    maxRow=0
    maxRowIndex=0
    maxColumn=0
    maxColumnIndex=0
    for i in range(m):
        Sum=0
        for j in range(n):
            Sum=Sum+arr[i][j]
        if Sum>maxRow:
            maxRowIndex=i
            maxRow=Sum
    for j in range(n):
        Sum=0
        for i in range(m):
            Sum=Sum+arr[i][j]
        if Sum>maxColumn:
            maxColumnIndex=j
            maxColumn=Sum
    
    if maxRow>=maxColumn:    
        print("row",maxRowIndex,maxRow)
    else:
        print("column",maxColumnIndex,maxColumn)


l1=[int(i) for i in input().strip().split(' ')]
m, n=l1[0], l1[1]
l2=[int(i) for i in input().strip().split(' ')]
arr = [ [ l2[(j*n)+i] for i in range(n)] for j in range(m)]
LargestRoworColumn(arr)
# Out:
# 20 30
# ...

# %% [markdown]
# # Spiral Print
# Given an N*M 2D array, print it in spiral form. That is, first you need to print the 1st row, then last column, then last row and then first column and so on.
# Print every element only once.
# # Input
# Line 1 : N and M, No. of rows & No. of columns (separated by space) followed by N*M  elements in row wise fashion.
# # Output
# Elements of matrix in spiral form in a single line and space separated

# %%
def spiralPrint(arr):
    k=0
    l=0
    i=0
    while i<n/2 :
        while l<(m-1-i):
            print(arr[k][l],end=" ")
            l = l+1
        print()
        while k<(n-1-i):
            print(arr[k][l],end=" ")
            k = k+1
        print()    
        while l>i:
            print(arr[k][l],end=" ")
            l=l-1
        print()
        while k>i:
            print(arr[k][l],end=" ")
            k=k-1
        print() 
        l=l+i+1
        k=k+i+1
        i=i+1
    

#Main
l=[int(i) for i in input().strip().split(' ')]
m, n=l[0], l[1]
arr = [ [ l[(j*n)+i+2] for i in range(n)] for j in range(m)]
spiralPrint(arr)
# Out:
# 3 1 10 20 30
# 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-049dfb70d5da> in <module>
#      29 m, n=l[0], l[1]
#      30 arr = [ [ l[(j*n)+i+2] for i in range(n)] for j in range(m)]
# ---> 31 spiralPrint(arr)
#
# <ipython-input-13-049dfb70d5da> in spiralPrint(arr)
#       5     while i<n/2 :
#       6         while l<(m-1-i):
# ----> 7             print(arr[k][l],end=" ")
#       8             l = l+1
#       9         print()
#
# IndexError: list index out of range

# %% [markdown]
# ## Printing maximum row and column

# %%
str = input().strip().split(" ")   #stores character of rows and columns

row = int(str[0])
column = int(str[1])

#taking elements in a single line separated by spaces
l = [int(i) for i in input().strip().split(" ")]
out2 = [[l[i*column + j] for j in range(column)] for i in range(row)]
print(out2)

max_sum = -100000
#columnwise sum
for j in range(column):
    column_sum = 0
    for i in range(row):                                     #ERROR
        column_sum = column_sum + out2[i][j]
    
    if column_sum > max_sum:
        s = column_sum
        max_sum = column_sum
        c = j
        string = 'column'
    elif column_sum == max_sum:
        break
    
    
max_row = 0
#rowwise sum
for i in range(row):
    row_sum = 0
    for j in range(column):
        row_sum = row_sum + out2[i][j]
    
    if row_sum > max_sum:
        s = row_sum
        max_sum = row_sum
        c = j
        string = 'row'
        
    
    
print(string, end=" ")
print(c, s)
# Out:
# 3 3
# 1 9 3 4 7 6 2 8 5
# [[1, 9, 3], [4, 7, 6], [2, 8, 5]]
# column 1 24
